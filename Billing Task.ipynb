# %%
# YOUR CODE HERE
Customers={}
ID=0
cont="C"
bill=0
while(cont=="C" or cont=="C"):
    Name=input("Enter your name")
    sweet=input("Do you want Frozen Yogurt or Ice cream? (Y: Frozen Yogurt, I: Ice cream)")
    container=input("What kind of container? (V: Cone, U: Cup)")
    if sweet=='Y' or sweet=='y':
        size=input("What size? (S: Small, M: Medium, L: Large)")
        if size=='S' or size=='s':
            bill=bill+300
            if(container=='V'or container=='v'):
                bill=bill+10
            elif(container=='U'or container=='u'):
                bill=bill+10
            else:
                print("Invalid Input")
                continue
        elif size=='M' or size=='M':
            bill=bill+400
            if(container=='V'or container=='v'):
                bill=bill+20
            elif(container=='U'or container=='u'):
                bill=bill+20
            else:
                print("Invalid Input")
                continue
        elif size=='L' or size=='l':
            bill=bill+500
            if(container=='V'or container=='v'):
                bill=bill+30
            elif(container=='U'or container=='u'):
                bill=bill+30
            else:
                print("Invalid Input")
                continue
    
    elif sweet=='I' or sweet=='i':
        Size=input("What size? (S: Small, M: Medium, L: Large)")
        if Size=='S' or Size=='s':
            bill=bill+400
            if(container=='V'or container=='v'):
                bill=bill+10
            elif(container=='U'or container=='u'):
                bill=bill+10
            else:
                print("Invalid Input")
                continue
        elif Size=='M' or Size=='M':
            bill=bill+500
            if(container=='V'or container=='v'):
                bill=bill+20
            elif(container=='U'or container=='u'):
                bill=bill+20
            else:
                print("Invalid Input")
                continue
        elif Size=='L' or Size=='l':
            bill=bill+600
            if(container=='V'or container=='v'):
                bill=bill+30
            elif(container=='U'or container=='u'):
                bill=bill+30
            else:
                print("Invalid Input")
                continue
    else:
        print("Invalid Input")
        continue
    Topping=input("Do you like to add a topping? (Y: Yes, N: No)")
    if Topping=="Y" or Topping=="y":
        bill=bill+75
        typet=input("What topping do you like? (G: Gummies, N: Nuts)")
        if typet=="G" or typet=="g":
            bill=bill+10
        elif typet=="N" or typet=="n":
            bill=bill+20
        else:
            print("Invalid Input")
            continue
    else:
        print("OK!! no Toppings are added to your Order")
    cookies=input("Do you like to have cookies? (Y: Yes, N: No)")
    if cookies=="Y" or cookies=="y":
        typec=input("What kind of cookies? (R: Raisin, C: Chocolate))")
        if typec=="R" or typec=="r":
            bill=bill+110
            sizec=input("And the size? (R: Regular, L: Large)")
            if sizec=="R" or sizec=="r":
                bill=bill+40
            elif sizec=="L" or sizec=="L":
                bill=bill+70
            else:
                print("Invalid Input")
                continue
        elif typec=="C" or typec=="C":
            bill=bill+120
            sizec=input("And the size? (R: Regular, L: Large)")
            if sizec=="R" or sizec=="r":
                bill=bill+40
            elif sizec=="L" or sizec=="L":
                bill=bill+70
            else:
                print("Invalid Input")
                continue
        else:
            print("Invalid Input")
            continue
    day=int(input("What day of the week is this? (1:Monday, 2:Tuesday, 3:Wednesday, 4:Thursday,5:Friday, 6:Saturday, 7:Sunday)"))
    if day==6 or day==7:
        print("Congrats!!! you got 10% weekend discount")
        discount=bill*10/100
        bill=bill-discount
    print("Your Total bill is : ",bill)
    check_dict=Name
    # Initialize a variable to track if the attribute exists
    name_exists = False
    # Iterate through the dictionary to check for the attribute
    for user_info in Customers.values():
        if check_dict in user_info:
            name_exists = True
            break  # Exit the loop early if the attribute is found
    if name_exists == True:
        user_info["TotalBill"] += bill 
    else:
        ID=ID+1
        new_customer={
            "Customer" : Name,
            "TotalBill" : bill
        }
        user_key = f"user{ID}"
        Customers[ID] = new_customer
    cont=input("Enter C to continue or Q to quit: C")
    if cont=="C"or cont=="c":
        continue
    else:
        break
    
print(Customers)
